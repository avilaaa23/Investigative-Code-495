# %%
import seaborn as sb
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from scipy.stats import chi2_contingency
from scipy.stats import chi2

# upload csv file by using pd.read_csv fuction must import pandas as pd for this function 
mono_nucleotide_data = pd.read_csv("final_nucleotide_composition.csv")

# Removes the % under the proportion data set to make it an intger
mono_nucleotide_data['proportion'] = mono_nucleotide_data['proportion'].str.rstrip('%').astype('float')

# Prints out Data Table 
mono_nucleotide_data
# Out:
#                      species    taxon nucleotide_counted     count  proportion
# 0           Enteromyxum leei  Myxozoa                  A      1531       18.11
# 1           Enteromyxum leei  Myxozoa                  T      3630       42.93
# 2           Enteromyxum leei  Myxozoa                  C      1329       15.72
# 3           Enteromyxum leei  Myxozoa                  G      1966       23.25
# 4      Henneguya salminicola  Myxozoa                  A   2038850       35.30
# 5      Henneguya salminicola  Myxozoa                  T   1842474       31.90
# 6      Henneguya salminicola  Myxozoa                  C    943750       16.34
# 7      Henneguya salminicola  Myxozoa                  G    951219       16.47
# 8               Kudoa iwatai  Myxozoa                  A      1858       24.51
# 9               Kudoa iwatai  Myxozoa                  T      3532       46.59
# 10              Kudoa iwatai  Myxozoa                  C      1045       13.78
# 11              Kudoa iwatai  Myxozoa                  G      1146       15.12
# 12       Myxobolus squamalis  Myxozoa                  A   1271670       33.66
# 13       Myxobolus squamalis  Myxozoa                  T   1190465       31.51
# 14       Myxobolus squamalis  Myxozoa                  C    654984       17.34
# 15       Myxobolus squamalis  Myxozoa                  G    660979       17.50
# 16     Thelohanellus kitauei  Myxozoa                  A   3517955       32.56
# 17     Thelohanellus kitauei  Myxozoa                  T   3076387       28.47
# 18     Thelohanellus kitauei  Myxozoa                  C   2087754       19.32
# 19     Thelohanellus kitauei  Myxozoa                  G   2122566       19.64
# 20       Acropora digitifera    Coral                  A  14274726       30.19
# 21       Acropora digitifera    Coral                  T  12218612       25.84
# 22       Acropora digitifera    Coral                  C   9712324       20.54
# 23       Acropora digitifera    Coral                  G  11082747       23.44
# 24    Pocillopora damicornis    Coral                  A  12421575       30.36
# 25    Pocillopora damicornis    Coral                  T  10447275       25.54
# 26    Pocillopora damicornis    Coral                  C   8429868       20.60
# 27    Pocillopora damicornis    Coral                  G   9613699       23.50
# 28  Nematostella vectensis\n    Coral                  A  19752247       28.70
# 29  Nematostella vectensis\n    Coral                  T  15798686       22.96
# 30  Nematostella vectensis\n    Coral                  C  16174753       23.50
# 31  Nematostella vectensis\n    Coral                  G  17089443       24.83
# 32     Exaiptasia diaphana\n    Coral                  A  14171337       32.12
# 33     Exaiptasia diaphana\n    Coral                  T  11456665       25.97
# 34     Exaiptasia diaphana\n    Coral                  C   8842995       20.05
# 35     Exaiptasia diaphana\n    Coral                  G   9642476       21.86
# 36            Hydra vulgaris    Coral                  A  20304119       35.63
# 37            Hydra vulgaris    Coral                  T  17577040       30.85
# 38            Hydra vulgaris    Coral                  C   8818855       15.48
# 39            Hydra vulgaris    Coral                  G  10282994       18.05

# %%
sns.set_context("talk")
sb.set_theme(style='white')
fig,ax = plt.subplots()

#Creates ViolinPlot & BoxPlot, Palette controls the colors of the data and hue creates the ledger 
sb.boxplot( x = 'nucleotide_counted',y = 'proportion', palette=['orange','lightsteelblue'], data = mono_nucleotide_data, hue = 'taxon' , boxprops={'alpha': .5}).set(title='Proportion vs Nucleotide Count')
sb.swarmplot( x = 'nucleotide_counted',y = 'proportion', palette=['orange','lightsteelblue'], data = mono_nucleotide_data, hue = 'taxon', dodge = True, zorder=.5, size=8 )

#Shift the ledger to the right
plt.legend(bbox_to_anchor=(1.35, 1), borderaxespad=0, frameon=False)

## Remove axis lines.
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

#Saves graph as a high resolution image on files
fig.savefig("Proportion_vs_Mono_Nucleotide_Count.png",dpi=300,bbox_inches="tight")

plt.show()

# %%
fig,ax = plt.subplots()
sb.set_context("talk")
sb.set_theme(style='white')

# Creates ViolinPlot, Palette controls the colors of the data and hue creates the ledger
sns.violinplot(x="nucleotide_counted", y="proportion", hue="taxon", data=mono_nucleotide_data, palette=['orange','lightsteelblue']).set(title='Proportion vs Nucleotide Count')

#Shift the ledger to the right
plt.legend(bbox_to_anchor=(1.35, 1), borderaxespad=0, frameon=False)

## Remove axis lines.
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

fig.savefig("Proportion_vs_mono_Nucleotide_Counted_Violin_Plot.png",dpi=300,bbox_inches="tight")
plt.show()

# %%
sb.set_style('white')
palette = sns.cubehelix_palette(start=.5, rot=-.5, dark=0.3, light=0.7)
ax = sns.violinplot(y="proportion", x="nucleotide_counted", data=mono_nucleotide_data, palette=['orange','lightsteelblue'], scale="width", inner=None)

xlim = ax.get_xlim()
ylim = ax.get_ylim()

for violin in ax.collections:
    bbox = violin.get_paths()[0].get_extents()
    x0, y0, width, height = bbox.bounds
    violin.set_clip_path(plt.Rectangle((x0, y0), width, height / 2, transform=ax.transData))

sns.boxplot(y="proportion", x="nucleotide_counted", data=mono_nucleotide_data, saturation=1, showfliers=False, width=0.3, boxprops={'zorder': 3, 'facecolor': 'none'}, ax=ax).set(title='Proportion vs Nucleotide Count')
old_len_collections = len(ax.collections)
sns.stripplot(y="proportion", x="nucleotide_counted", data=mono_nucleotide_data, ax=ax, hue="taxon")
for dots in ax.collections[old_len_collections:]:
    dots.set_offsets(dots.get_offsets() + np.array([0, 0.1]))

plt.legend(bbox_to_anchor=(1.35, 1), borderaxespad=0, frameon=False)

ax.set_xlim(xlim)
ax.set_ylim(ylim)

ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

fig.savefig("Proportion_vs_mono_Nucleotide_Counted_Violi_Plot.png",dpi=300,bbox_inches="tight")
plt.show()

# %%
Thelohanellus_kitauei_dinucleotide_data = pd.read_csv("Thelohanellus_kitauei_dinucleotide_analysis.csv")
Thelohanellus_kitauei_dinucleotide_data.round({"CG_to_GC_Ratio":1})

Thelohanellus_kitauei_dinucleotide_data
# Out:
#       Unnamed: 0                Species Unnamed: 2  \
# 0          10377  Thelohanellus_kitauei    #VALUE!
# 1           5342  Thelohanellus_kitauei    #VALUE!
# 2          14239  Thelohanellus_kitauei    #VALUE!
# 3          11520  Thelohanellus_kitauei    #VALUE!
# 4           7905  Thelohanellus_kitauei    #VALUE!
# ...          ...                    ...        ...
# 4351        2847  Thelohanellus_kitauei    #VALUE!
# 4352        8680  Thelohanellus_kitauei    #VALUE!
# 4353        7752  Thelohanellus_kitauei    #VALUE!
# 4354       14513  Thelohanellus_kitauei    #VALUE!
# 4355        4556  Thelohanellus_kitauei    #VALUE!
#
#                                                 Gene ID  \
# 0     lcl|JWZT01004076.1_cds_KII64896.1_10378 [locus...
# 1     lcl|JWZT01002262.1_cds_KII69877.1_5343 [locus_...
# 2     lcl|JWZT01005390.1_cds_KII60943.1_14240 [locus...
# 3     lcl|JWZT01004623.1_cds_KII63634.1_11521 [locus...
# 4     lcl|JWZT01003236.1_cds_KII67324.1_7906 [locus_...
# ...                                                 ...
# 4351  lcl|JWZT01001256.1_cds_KII72382.1_2848 [locus_...
# 4352  lcl|JWZT01003512.1_cds_KII66510.1_8681 [locus_...
# 4353  lcl|JWZT01003177.1_cds_KII67473.1_7753 [locus_...
# 4354  lcl|JWZT01005495.1_cds_KII60712.1_14514 [locus...
# 4355  lcl|JWZT01001996.1_cds_KII70686.1_4557 [locus_...
#
#       CG Dinucleotide Content  GC Content  Index  CG_to_GC_Ratio
# 0                           0          98    1.0        0.000000
# 1                           3         146    2.0        0.020548
# 2                           5         207    3.0        0.024155
# 3                          11         434    4.0        0.025346
# 4                           5         164    5.0        0.030488
# ...                       ...         ...    ...             ...
# 4351                       68         351    NaN        0.193732
# 4352                       53         268    NaN        0.197761
# 4353                       43         217    NaN        0.198157
# 4354                       36         156    NaN        0.230769
# 4355                       45         184    NaN        0.244565
#
# [4356 rows x 8 columns]

# %%
sns.set_context("talk")
sb.set_theme(style='white')
fig,ax = plt.subplots()

#Creates ViolinPlot & BoxPlot, Palette controls the colors of the data and hue creates the ledger 
sb.lineplot( x = 'Index',y = 'CG_to_GC_Ratio', palette=['orange','lightsteelblue'], data = Thelohanellus_kitauei_dinucleotide_data).set(title = 'Thelohanellus Kitauei CG to GC Ratio')



## Remove axis lines.
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

fig.savefig("Thelohanellus_kitauei_dinucleotide.png",dpi=300,bbox_inches="tight")

plt.show()

# %%
Enteromyxum_leei_dinucleotide_data = pd.read_csv("Enteromyxum_leei_dinucleotide_analysis.csv")
Enteromyxum_leei_dinucleotide_data.round({"CG_to_GC_Ratio":1})

Enteromyxum_leei_dinucleotide_data
# Out:
#     Unnamed: 0           Species Unnamed: 2  \
# 0            0  Enteromyxum_leei    #VALUE!
# 1            1  Enteromyxum_leei    #VALUE!
# 2            2  Enteromyxum_leei    #VALUE!
# 3            3  Enteromyxum_leei    #VALUE!
# 4            4  Enteromyxum_leei    #VALUE!
# 5            5  Enteromyxum_leei    #VALUE!
# 6            6  Enteromyxum_leei    #VALUE!
# 7            7  Enteromyxum_leei    #VALUE!
# 8            8  Enteromyxum_leei    #VALUE!
# 9            9  Enteromyxum_leei    #VALUE!
# 10          10  Enteromyxum_leei    #VALUE!
# 11          11  Enteromyxum_leei    #VALUE!
# 12          12  Enteromyxum_leei    #VALUE!
#
#                                               Gene ID  \
# 0   lcl|LN868201.1_cds_CRX66570.1_1 [gene=nad5] [p...
# 1   lcl|LN868202.1_cds_CRX66571.1_2 [gene=cox1] [p...
# 2   lcl|LN868203.1_cds_CRX66572.1_3 [protein_id=CR...
# 3   lcl|LN868203.1_cds_CRX66573.1_4 [protein_id=CR...
# 4   lcl|LN868203.1_cds_CRX66574.1_5 [protein_id=CR...
# 5   lcl|LN868203.1_cds_CRX66575.1_6 [protein_id=CR...
# 6   lcl|LN868204.1_cds_CRX66576.1_7 [protein_id=CR...
# 7   lcl|LN868204.1_cds_CRX66577.1_8 [protein_id=CR...
# 8   lcl|LN868205.1_cds_CRX66578.1_9 [gene=nad1] [p...
# 9   lcl|LN868206.1_cds_CRX66579.1_10 [transl_excep...
# 10  lcl|LN868206.1_cds_CRX66580.1_11 [gene=cox2] [...
# 11  lcl|LN868207.2_cds_SMY14786.1_12 [db_xref=GOA:...
# 12  lcl|LN868207.2_cds_CRX66581.1_13 [gene=cob] [d...
#
#     CG Dinucleotide Content  GC Content  Index  CG_to_GC_Ratio
# 0                         9         438      1        0.008197
# 1                        17         547      2        0.016393
# 2                         3         122      3        0.020548
# 3                         1          61      4        0.024390
# 4                         4         103      5        0.024590
# 5                         1         122      6        0.025974
# 6                         6         128      7        0.029412
# 7                        10         297      8        0.030534
# 8                        10         385      9        0.031079
# 9                         8         262     10        0.033670
# 10                        8         272     11        0.033784
# 11                        5         148     12        0.038835
# 12                       10         410     13        0.046875

# %%
sns.set_context("talk")
sb.set_theme(style='white')
fig,ax = plt.subplots()

#Creates ViolinPlot & BoxPlot, Palette controls the colors of the data and hue creates the ledger 
sb.lineplot( x = 'Index',y = 'CG_to_GC_Ratio', palette=['orange','lightsteelblue'], data = Enteromyxum_leei_dinucleotide_data).set(title = 'Enteromyxum Leei CG to GC Ratio')



## Remove axis lines.
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

fig.savefig("Enteromyxum_leei_dinucleotide.png",dpi=300,bbox_inches="tight")

plt.show()

# %%
Henneguya_salminicola_dinucleotide_data = pd.read_csv("Henneguya_salminicola_dinucleotide_analysis.csv")
Henneguya_salminicola_dinucleotide_data.round({"CG_to_GC_Ratio":1})

Henneguya_salminicola_dinucleotide_data
# Out:
#       Unnamed: 0                Species  Unnamed: 2  \
# 0              0  Henneguya_salminicola          69
# 1              1  Henneguya_salminicola          69
# 2              2  Henneguya_salminicola          69
# 3              3  Henneguya_salminicola          69
# 4              4  Henneguya_salminicola          69
# ...          ...                    ...         ...
# 8182        8182  Henneguya_salminicola          72
# 8183        8183  Henneguya_salminicola          72
# 8184        8184  Henneguya_salminicola          72
# 8185        8185  Henneguya_salminicola          72
# 8186        8186  Henneguya_salminicola          72
#
#                                                 Gene ID  \
# 0     lcl|SGJC01000001.1_cds_KAF0993424.1_1 [locus_t...
# 1     lcl|SGJC01000001.1_cds_KAF0993421.1_2 [locus_t...
# 2     lcl|SGJC01000001.1_cds_KAF0993420.1_3 [locus_t...
# 3     lcl|SGJC01000001.1_cds_KAF0993423.1_4 [locus_t...
# 4     lcl|SGJC01000001.1_cds_KAF0993426.1_5 [locus_t...
# ...                                                 ...
# 8182  lcl|SGJC01018262.1_cds_KAF0985244.1_8183 [locu...
# 8183  lcl|SGJC01018294.1_cds_KAF0985243.1_8184 [locu...
# 8184  lcl|SGJC01018314.1_cds_KAF0985242.1_8185 [locu...
# 8185  lcl|SGJC01018318.1_cds_KAF0985241.1_8186 [locu...
# 8186  lcl|SGJC01018325.1_cds_KAF0985240.1_8187 [locu...
#
#       CG Dinucleotide Content  GC Content  Index  CG_to_GC_Ratio
# 0                           8          99      1        0.000000
# 1                          14         117      2        0.000000
# 2                          35         395      3        0.000000
# 3                          21         214      4        0.000000
# 4                           2          50      5        0.000000
# ...                       ...         ...    ...             ...
# 8182                        4          69   8183        0.189474
# 8183                       12         149   8184        0.200000
# 8184                        6          94   8185        0.200000
# 8185                       10         115   8186        0.208955
# 8186                       15         125   8187        0.212500
#
# [8187 rows x 8 columns]

# %%
sns.set_context("talk")
sb.set_theme(style='white')
fig,ax = plt.subplots()

#Creates ViolinPlot & BoxPlot, Palette controls the colors of the data and hue creates the ledger 
sb.lineplot( x = 'Index',y = 'CG_to_GC_Ratio', palette=['orange','lightsteelblue'], data = Henneguya_salminicola_dinucleotide_data).set(title = 'Henneguya Salminicola CG to GC Ratio')



## Remove axis lines.
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

fig.savefig("Henneguya_salminicola_dinucleotide.png",dpi=300,bbox_inches="tight")


plt.show()

# %%
Myxobolus_squamalis_dinucleotide_data = pd.read_csv("Myxobolus_squamalis_dinucleotide_analysis.csv")
Myxobolus_squamalis_dinucleotide_data.round({"CG_to_GC_Ratio":1})

Myxobolus_squamalis_dinucleotide_data
# Out:
#       Unnamed: 0              Species  Unnamed: 2  \
# 0            205  Myxobolus_squamalis          68
# 1            551  Myxobolus_squamalis          68
# 2              8  Myxobolus_squamalis          69
# 3             28  Myxobolus_squamalis          69
# 4            855  Myxobolus_squamalis          69
# ...          ...                  ...         ...
# 5718        4315  Myxobolus_squamalis          72
# 5719        3857  Myxobolus_squamalis          72
# 5720        5312  Myxobolus_squamalis          72
# 5721        2686  Myxobolus_squamalis          72
# 5722        5509  Myxobolus_squamalis          72
#
#                                                 Gene ID  \
# 0     lcl|QWKW01000122.1_cds_KAF1745391.1_206 [locus...
# 1     lcl|QWKW01000383.1_cds_KAF1745045.1_552 [locus...
# 2     lcl|QWKW01000005.1_cds_KAF1745588.1_9 [locus_t...
# 3     lcl|QWKW01000021.1_cds_KAF1745568.1_29 [locus_...
# 4     lcl|QWKW01000645.1_cds_KAF1744741.1_856 [locus...
# ...                                                 ...
# 5718  lcl|QWKW01009178.1_cds_KAF1741281.1_4316 [locu...
# 5719  lcl|QWKW01006555.1_cds_KAF1741739.1_3858 [locu...
# 5720  lcl|QWKW01023437.1_cds_KAF1740285.1_5313 [locu...
# 5721  lcl|QWKW01003209.1_cds_KAF1742910.1_2687 [locu...
# 5722  lcl|QWKW01030574.1_cds_KAF1740087.1_5510 [locu...
#
#       CG Dinucleotide Content  GC Content  Index  CG_to_GC_Ratio
# 0                         108        1537      1        0.000000
# 1                           2          28      2        0.000000
# 2                           2         132      3        0.000000
# 3                           1          61      4        0.000000
# 4                          17         535      5        0.000000
# ...                       ...         ...    ...             ...
# 5718                       16          94   5719        0.170213
# 5719                        7          41   5720        0.170732
# 5720                        3          17   5721        0.176471
# 5721                        7          39   5722        0.179487
# 5722                        1           4   5723        0.250000
#
# [5723 rows x 8 columns]

# %%
sns.set_context("talk")
sb.set_theme(style='white')
fig,ax = plt.subplots()

#Creates ViolinPlot & BoxPlot, Palette controls the colors of the data and hue creates the ledger 
sb.lineplot( x = 'Index',y = 'CG_to_GC_Ratio', palette=['orange','lightsteelblue'], data = Myxobolus_squamalis_dinucleotide_data).set(title = 'Myxobolus Squamalis CG to GC Ratio')



## Remove axis lines.
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

fig.savefig("Myxobolus_squamalis_dinucleotide.png",dpi=300,bbox_inches="tight")

plt.show()

# %%
Kudoa_iwata_dinucleotide_data = pd.read_csv("Kudoa_iwata_dinucleotide_analysis.csv")
Kudoa_iwata_dinucleotide_data.round({"CG_to_GC_Ratio":1})

Kudoa_iwata_dinucleotide_data
# Out:
#    Unnamed: 0      Species Unnamed: 2  \
# 0           1  Kudoa_iwata    #VALUE!
# 1           3  Kudoa_iwata    #VALUE!
# 2           7  Kudoa_iwata    #VALUE!
# 3           8  Kudoa_iwata    #VALUE!
# 4           9  Kudoa_iwata    #VALUE!
# 5           6  Kudoa_iwata    #VALUE!
# 6           0  Kudoa_iwata    #VALUE!
# 7           2  Kudoa_iwata    #VALUE!
# 8           5  Kudoa_iwata    #VALUE!
# 9           4  Kudoa_iwata    #VALUE!
#
#                                              Gene ID  CG Content  GC Content  \
# 0  lcl|LT671462.1_cds_SHO28748.1_2 [protein_id=SH...           0          94
# 1  lcl|LT671462.1_cds_SHO28750.1_4 [gene=cob] [pr...           0         318
# 2  lcl|LT671462.1_cds_SHO28754.1_8 [gene=cox2] [p...           0         182
# 3  lcl|LT671462.1_cds_SHO28755.1_9 [protein_id=SH...           0          86
# 4  lcl|LT671462.1_cds_SHO28756.1_10 [protein_id=S...           0         110
# 5  lcl|LT671462.1_cds_SHO28753.1_7 [gene=nad5] [p...           1         270
# 6  lcl|LT671462.1_cds_SHO28747.1_1 [gene=cox1] [p...           3         485
# 7  lcl|LT671462.1_cds_SHO33068.1_3 [protein_id=SH...           2         259
# 8  lcl|LT671462.1_cds_SHO28752.1_6 [protein_id=SH...           2         174
# 9  lcl|LT671462.1_cds_SHO28751.1_5 [gene=nad1] [p...           3         213
#
#    index  CG_to_GC_Ratio
# 0      1        0.000000
# 1      2        0.000000
# 2      3        0.000000
# 3      4        0.000000
# 4      5        0.000000
# 5      6        0.003704
# 6      7        0.006186
# 7      8        0.007722
# 8      9        0.011494
# 9     10        0.014085

# %%
sns.set_context("talk")
sb.set_theme(style='white')
fig,ax = plt.subplots()

#Creates ViolinPlot & BoxPlot, Palette controls the colors of the data and hue creates the ledger 
sb.lineplot( x = 'index',y = 'CG_to_GC_Ratio', palette=['orange','lightsteelblue'], data = Kudoa_iwata_dinucleotide_data).set(title = 'Kudoa Iwata CG to GC Ratio')




## Remove axis lines.
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

fig.savefig("Kudoa_iwata_dinucleotide.png",dpi=300,bbox_inches="tight")

plt.show()

# %%
Acropora_digitifera_dinucleotide_data = pd.read_csv("Acropora_digitifera_dinucleotide_analysis.csv")
Acropora_digitifera_dinucleotide_data.round({"CG_to_GC_Ratio":1})

Acropora_digitifera_dinucleotide_data
# Out:
#        Unnamed: 0              Species Unnamed: 2  \
# 0             543  Acropora_digitifera    #VALUE!
# 1             616  Acropora_digitifera    #VALUE!
# 2            1985  Acropora_digitifera    #VALUE!
# 3            2051  Acropora_digitifera    #VALUE!
# 4            7252  Acropora_digitifera    #VALUE!
# ...           ...                  ...        ...
# 33873       10279  Acropora_digitifera    #VALUE!
# 33874        2333  Acropora_digitifera    #VALUE!
# 33875       14889  Acropora_digitifera    #VALUE!
# 33876       29596  Acropora_digitifera    #VALUE!
# 33877       32842  Acropora_digitifera    #VALUE!
#
#                                                  Gene ID  \
# 0      lcl|NW_015441059.1_cds_XP_015752646.1_544 [gen...
# 1      lcl|NW_015441059.1_cds_XP_015752784.1_617 [gen...
# 2      lcl|NW_015441068.1_cds_XP_015768257.1_1986 [ge...
# 3      lcl|NW_015441068.1_cds_XP_015769989.1_2052 [ge...
# 4      lcl|NW_015441119.1_cds_XP_015755180.1_7253 [ge...
# ...                                                  ...
# 33873  lcl|NW_015441162.1_cds_XP_015758562.1_10280 [g...
# 33874  lcl|NW_015441070.1_cds_XP_015772277.1_2334 [ge...
# 33875  lcl|NW_015441245.1_cds_XP_015763672.1_14890 [g...
# 33876  lcl|NW_015441848.1_cds_XP_015780046.1_29597 [g...
# 33877  lcl|NW_015442423.1_cds_XP_015749812.1_32843 [g...
#
#        CG Dinucleotide Content  GC Content  Index  CG_to_GC_Ratio
# 0                            0         129      1        0.000000
# 1                            0         108      2        0.000000
# 2                            0         122      3        0.000000
# 3                            0         124      4        0.000000
# 4                            0         139      5        0.000000
# ...                        ...         ...    ...             ...
# 33873                       43         214  33874        0.200935
# 33874                       38         180  33875        0.211111
# 33875                       71         292  33876        0.243151
# 33876                       28          98  33877        0.285714
# 33877                      137         424  33878        0.323113
#
# [33878 rows x 8 columns]

# %%
sns.set_context("talk")
sb.set_theme(style='white')
fig,ax = plt.subplots()

#Creates ViolinPlot & BoxPlot, Palette controls the colors of the data and hue creates the ledger 
sb.lineplot( x = 'Index',y = 'CG_to_GC_Ratio', palette=['orange'], data = Acropora_digitifera_dinucleotide_data).set(title = 'Acropora Digitifera CG to GC Ratio')



## Remove axis lines.
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

fig.savefig("Acropora_digitifera_dinucleotide.png",dpi=300,bbox_inches="tight")

plt.show()

# %%
Pocillopora_damicornis_dinucleotide_data = pd.read_csv("Pocillopora_damicornis_dinucleotide_analysis.csv")
Pocillopora_damicornis_dinucleotide_data.round({"CG_to_GC_Ratio":1})

Pocillopora_damicornis_dinucleotide_data
# Out:
#        Unnamed: 0                 Species Unnamed: 2  \
# 0            1536  Pocillopora_damicornis    #VALUE!
# 1            3319  Pocillopora_damicornis    #VALUE!
# 2            3825  Pocillopora_damicornis    #VALUE!
# 3            5145  Pocillopora_damicornis    #VALUE!
# 4            8169  Pocillopora_damicornis    #VALUE!
# ...           ...                     ...        ...
# 25178       11157  Pocillopora_damicornis    #VALUE!
# 25179       11054  Pocillopora_damicornis    #VALUE!
# 25180        4615  Pocillopora_damicornis    #VALUE!
# 25181       12619  Pocillopora_damicornis    #VALUE!
# 25182       12620  Pocillopora_damicornis    #VALUE!
#
#                                                  Gene ID  \
# 0      lcl|NW_020843646.1_cds_XP_027049352.1_1537 [ge...
# 1      lcl|NW_020843958.1_cds_XP_027035692.1_3320 [ge...
# 2      lcl|NW_020844078.1_cds_XP_027036248.1_3826 [ge...
# 3      lcl|NW_020844297.1_cds_XP_027037728.1_5146 [ge...
# 4      lcl|NW_020844818.1_cds_XP_027041052.1_8170 [ge...
# ...                                                  ...
# 25178  lcl|NW_020845377.1_cds_XP_027044375.1_11158 [g...
# 25179  lcl|NW_020845351.1_cds_XP_027044323.1_11055 [g...
# 25180  lcl|NW_020844198.1_cds_XP_027037123.1_4616 [ge...
# 25181  lcl|NW_020845585.1_cds_XP_027046005.1_12620 [g...
# 25182  lcl|NW_020845585.1_cds_XP_027046006.1_12621 [g...
#
#        CG Dinucleotide Content  GC Content  index  CG_to_GC_Ratio
# 0                            0         222      1        0.000000
# 1                            0         119      2        0.000000
# 2                            0         104      3        0.000000
# 3                            0         212      4        0.000000
# 4                            0         138      5        0.000000
# ...                        ...         ...    ...             ...
# 25178                       48         265  25179        0.181132
# 25179                       22         120  25180        0.183333
# 25180                      225        1186  25181        0.189713
# 25181                       64         329  25182        0.194529
# 25182                       64         303  25183        0.211221
#
# [25183 rows x 8 columns]

# %%
sns.set_context("talk")
sb.set_theme(style='white')
fig,ax = plt.subplots()

#Creates ViolinPlot & BoxPlot, Palette controls the colors of the data and hue creates the ledger 
sb.lineplot( x = 'index',y = 'CG_to_GC_Ratio', palette=['orange','lightsteelblue'], data = Pocillopora_damicornis_dinucleotide_data).set(title = 'Pocillopora Damicornis CG to GC Ratio')




## Remove axis lines.
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

fig.savefig("Pocillopora_damicornis_dinucleotide.png",dpi=300,bbox_inches="tight")

plt.show()

# %%
Nematostella_vectensis_dinucleotide_data = pd.read_csv("Nematostella_vectensis_dinucleotide_analysis.csv")
Nematostella_vectensis_dinucleotide_data.round({"CG_to_GC_Ratio":1})

Nematostella_vectensis_dinucleotide_data
# Out:
#        Unnamed: 0                 Species Unnamed: 2  \
# 0               0  Nematostella_vectensis    #VALUE!
# 1               1  Nematostella_vectensis    #VALUE!
# 2               2  Nematostella_vectensis    #VALUE!
# 3               3  Nematostella_vectensis    #VALUE!
# 4               4  Nematostella_vectensis    #VALUE!
# ...           ...                     ...        ...
# 32365       32365  Nematostella_vectensis    #VALUE!
# 32366       32366  Nematostella_vectensis    #VALUE!
# 32367       32367  Nematostella_vectensis    #VALUE!
# 32368       32368  Nematostella_vectensis    #VALUE!
# 32369       32369  Nematostella_vectensis    #VALUE!
#
#                                                  Gene ID  \
# 0      lcl|NC_064034.1_cds_XP_048580524.1_1 [gene=LOC...
# 1      lcl|NC_064034.1_cds_XP_048580530.1_2 [gene=LOC...
# 2      lcl|NC_064034.1_cds_XP_048580535.1_3 [gene=LOC...
# 3      lcl|NC_064034.1_cds_XP_032230053.2_4 [gene=LOC...
# 4      lcl|NC_064034.1_cds_XP_048580518.1_5 [gene=LOC...
# ...                                                  ...
# 32365  lcl|NW_026019279.1_cds_XP_048579159.1_32366 [g...
# 32366  lcl|NW_026019282.1_cds_XP_048579163.1_32367 [g...
# 32367  lcl|NW_026019282.1_cds_XP_048579161.1_32368 [g...
# 32368  lcl|NW_026019282.1_cds_XP_048579162.1_32369 [g...
# 32369  lcl|NW_026019282.1_cds_XP_048579164.1_32370 [g...
#
#        CG Dinucleotide Content  GC Content  Index  CG_to_GC_Ratio
# 0                          655        6355      1        0.000000
# 1                          655        6355      2        0.000000
# 2                          655        6347      3        0.000000
# 3                          655        6357      4        0.000000
# 4                          655        6357      5        0.000000
# ...                        ...         ...    ...             ...
# 32365                       82         774  32366        0.209567
# 32366                      101         650  32367        0.216110
# 32367                      102         657  32368        0.222513
# 32368                      102         657  32369        0.231481
# 32369                       83         535  32370        0.250836
#
# [32370 rows x 8 columns]

# %%
sns.set_context("talk")
sb.set_theme(style='white')
fig,ax = plt.subplots()

#Creates ViolinPlot & BoxPlot, Palette controls the colors of the data and hue creates the ledger 
sb.lineplot( x = 'Index',y = 'CG_to_GC_Ratio', palette=['orange','lightsteelblue'], data = Nematostella_vectensis_dinucleotide_data).set(title = 'Nematostella Vectensis CG to GC Ratio')



## Remove axis lines.
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

fig.savefig("Nematostella_vectensis_dinucleotide.png",dpi=300,bbox_inches="tight")

plt.show()

# %%
Exaiptasia_diaphana_dinucleotide_data = pd.read_csv("Exaiptasia_diaphana_dinucleotide_analysis.csv")
Exaiptasia_diaphana_dinucleotide_data.round({"CG_to_GC_Ratio":1})

Exaiptasia_diaphana_dinucleotide_data
# Out:
#        Unnamed: 0              Species Unnamed: 2  \
# 0             257  Exaiptasia_diaphana    #VALUE!
# 1             902  Exaiptasia_diaphana    #VALUE!
# 2            1673  Exaiptasia_diaphana    #VALUE!
# 3            1877  Exaiptasia_diaphana    #VALUE!
# 4            2433  Exaiptasia_diaphana    #VALUE!
# ...           ...                  ...        ...
# 27748       19893  Exaiptasia_diaphana    #VALUE!
# 27749       11495  Exaiptasia_diaphana    #VALUE!
# 27750       18939  Exaiptasia_diaphana    #VALUE!
# 27751        5573  Exaiptasia_diaphana    #VALUE!
# 27752       18266  Exaiptasia_diaphana    #VALUE!
#
#                                                  Gene ID  \
# 0      lcl|NW_018384102.1_cds_XP_028517869.1_258 [gen...
# 1      lcl|NW_018384181.1_cds_XP_020897611.1_903 [gen...
# 2      lcl|NW_018384256.1_cds_XP_020905342.1_1674 [ge...
# 3      lcl|NW_018384289.1_cds_XP_020907434.1_1878 [ge...
# 4      lcl|NW_018384354.1_cds_XP_020913527.2_2434 [ge...
# ...                                                  ...
# 27748  lcl|NW_018387547.1_cds_XP_028517259.1_19894 [g...
# 27749  lcl|NW_018385529.1_cds_XP_020900121.1_11496 [g...
# 27750  lcl|NW_018387208.1_cds_XP_028516940.1_18940 [g...
# 27751  lcl|NW_018384750.1_cds_XP_028513098.1_5574 [ge...
# 27752  lcl|NW_018386934.1_cds_XP_028516745.1_18267 [g...
#
#        CG Dinucleotide Content   GC Content  Index  CG_to_GC_Ratio
# 0                             0         109      1        0.000000
# 1                             0          89      2        0.000000
# 2                             0          97      3        0.000000
# 3                             0          39      4        0.000000
# 4                             0         139      5        0.000000
# ...                         ...         ...    ...             ...
# 27748                        48         238  27749        0.201681
# 27749                        52         257  27750        0.202335
# 27750                        62         302  27751        0.205298
# 27751                       579        2809  27752        0.206123
# 27752                        31         146  27753        0.212329
#
# [27753 rows x 8 columns]

# %%
sns.set_context("talk")
sb.set_theme(style='white')
fig,ax = plt.subplots()

#Creates ViolinPlot & BoxPlot, Palette controls the colors of the data and hue creates the ledger 
sb.lineplot( x = 'Index',y = 'CG_to_GC_Ratio', palette=['orange','lightsteelblue'], data = Exaiptasia_diaphana_dinucleotide_data).set(title = 'Exaiptasia Diaphana CG to GC Ratio')




## Remove axis lines.
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

fig.savefig("Exaiptasia_diaphana_dinucleotide.png",dpi=300,bbox_inches="tight")


plt.show()

# %%
Hydra_vulgaris_dinucleotide_data = pd.read_csv("Hydra_vulgaris_dinucleotide_analysis.csv")
Hydra_vulgaris_dinucleotide_data.round({"CG_to_GC_Ratio":1})

Hydra_vulgaris_dinucleotide_data
# Out:
#        Unnamed: 0         Species Unnamed: 2  \
# 0               0  Hydra_vulgaris    #VALUE!
# 1               1  Hydra_vulgaris    #VALUE!
# 2               2  Hydra_vulgaris    #VALUE!
# 3               3  Hydra_vulgaris    #VALUE!
# 4               4  Hydra_vulgaris    #VALUE!
# ...           ...             ...        ...
# 32698       32698  Hydra_vulgaris    #VALUE!
# 32699       32699  Hydra_vulgaris    #VALUE!
# 32700       32700  Hydra_vulgaris    #VALUE!
# 32701       32701  Hydra_vulgaris    #VALUE!
# 32702       32702  Hydra_vulgaris    #VALUE!
#
#                                                  Gene ID  \
# 0      lcl|NC_061156.1_cds_XP_047132677.1_1 [gene=LOC...
# 1      lcl|NC_061156.1_cds_XP_047131986.1_2 [gene=LOC...
# 2      lcl|NC_061156.1_cds_XP_047134143.1_3 [gene=LOC...
# 3      lcl|NC_061156.1_cds_XP_047134647.1_4 [gene=LOC...
# 4      lcl|NC_061156.1_cds_XP_047135815.1_5 [gene=LOC...
# ...                                                  ...
# 32698  lcl|NC_011221.1_cds_YP_002221534.1_32699 [gene...
# 32699  lcl|NC_011221.1_cds_YP_002221535.1_32700 [gene...
# 32700  lcl|NC_011221.1_cds_YP_002221536.1_32701 [gene...
# 32701  lcl|NC_011221.1_cds_YP_002221537.1_32702 [gene...
# 32702  lcl|NC_011221.1_cds_YP_002221538.1_32703 [gene...
#
#        CG Dinucleotide Content  GC Content  Index  CG_to_GC_Ratio
# 0                            9         203      1        0.000000
# 1                           12         218      2        0.000000
# 2                            5         115      3        0.000000
# 3                            5         115      4        0.000000
# 4                            0         164      5        0.000000
# ...                        ...         ...    ...             ...
# 32698                        0          57  32699        0.166667
# 32699                        2         226  32700        0.166667
# 32700                        5         302  32701        0.168317
# 32701                        9         281  32702        0.168317
# 32702                        5         472  32703        0.190476
#
# [32703 rows x 8 columns]

# %%
sns.set_context("talk")
sb.set_theme(style='white')
fig,ax = plt.subplots()

#Creates ViolinPlot & BoxPlot, Palette controls the colors of the data and hue creates the ledger 
sb.lineplot( x = 'Index',y = 'CG_to_GC_Ratio', palette=['orange','lightsteelblue'], data = Hydra_vulgaris_dinucleotide_data).set(title = 'Hydra Vulgaris CG to GC Ratio')



## Remove axis lines.
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

fig.savefig("Hydra_vulgaris_dinucleotide.png",dpi=300,bbox_inches="tight")

plt.show()

# %%
rows_with_A = mono_nucleotide_data['nucleotide_counted'] == 'A'
nucleotide_A_data = mono_nucleotide_data[rows_with_A]

nucleotide_A_data
# Out:
#                      species    taxon nucleotide_counted     count  proportion
# 0           Enteromyxum leei  Myxozoa                  A      1531       18.11
# 4      Henneguya salminicola  Myxozoa                  A   2038850       35.30
# 8               Kudoa iwatai  Myxozoa                  A      1858       24.51
# 12       Myxobolus squamalis  Myxozoa                  A   1271670       33.66
# 16     Thelohanellus kitauei  Myxozoa                  A   3517955       32.56
# 20       Acropora digitifera    Coral                  A  14274726       30.19
# 24    Pocillopora damicornis    Coral                  A  12421575       30.36
# 28  Nematostella vectensis\n    Coral                  A  19752247       28.70
# 32     Exaiptasia diaphana\n    Coral                  A  14171337       32.12
# 36            Hydra vulgaris    Coral                  A  20304119       35.63

# %%
import statsmodels as sm
import statsmodels.formula.api as smf

nucleotides = ['A','T','C','G']
for nucleotide in nucleotides:
    rows_with_A = mono_nucleotide_data['nucleotide_counted'] == nucleotide
    nucleotide_A_data = mono_nucleotide_data[rows_with_A]
    print(f'analyzing nucleotide composition {nucleotide}')
    
    nucleotide_A_data
    model = smf.ols(formula='proportion ~ taxon', data=nucleotide_A_data)
    results = model.fit()
    summary = results.summary()
    print(summary)
    output_file = open(f"nucleotide_{nucleotide}_Stats_Results.txt", "w")
    output_file.write(str(summary))
    output_file.close()
# Out:
# analyzing nucleotide composition A
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             proportion   R-squared:                       0.064
# Model:                            OLS   Adj. R-squared:                 -0.053
# Method:                 Least Squares   F-statistic:                    0.5491
# Date:                Wed, 15 Mar 2023   Prob (F-statistic):              0.480
# Time:                        21:58:32   Log-Likelihood:                -30.099
# No. Observations:                  10   AIC:                             64.20
# Df Residuals:                       8   BIC:                             64.80
# Df Model:                           1
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# Intercept           31.4000      2.454     12.794      0.000      25.741      37.059
# taxon[T.Myxozoa]    -2.5720      3.471     -0.741      0.480     -10.576       5.432
# ==============================================================================
# Omnibus:                        1.953   Durbin-Watson:                   2.275
# Prob(Omnibus):                  0.377   Jarque-Bera (JB):                0.818
# Skew:                          -0.695   Prob(JB):                        0.664
# Kurtosis:                       2.828   Cond. No.                         2.62
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# analyzing nucleotide composition T
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             proportion   R-squared:                       0.469
# Model:                            OLS   Adj. R-squared:                  0.402
# Method:                 Least Squares   F-statistic:                     7.056
# Date:                Wed, 15 Mar 2023   Prob (F-statistic):             0.0290
# Time:                        21:58:32   Log-Likelihood:                -30.960
# No. Observations:                  10   AIC:                             65.92
# Df Residuals:                       8   BIC:                             66.52
# Df Model:                           1
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# Intercept           26.2320      2.675      9.807      0.000      20.064      32.400
# taxon[T.Myxozoa]    10.0480      3.783      2.656      0.029       1.325      18.771
# ==============================================================================
# Omnibus:                        0.835   Durbin-Watson:                   2.337
# Prob(Omnibus):                  0.659   Jarque-Bera (JB):                0.671
# Skew:                           0.512   Prob(JB):                        0.715
# Kurtosis:                       2.250   Cond. No.                         2.62
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# analyzing nucleotide composition C
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             proportion   R-squared:                       0.384
# Model:                            OLS   Adj. R-squared:                  0.307
# Method:                 Least Squares   F-statistic:                     4.994
# Date:                Wed, 15 Mar 2023   Prob (F-statistic):             0.0559
# Time:                        21:58:32   Log-Likelihood:                -22.238
# No. Observations:                  10   AIC:                             48.48
# Df Residuals:                       8   BIC:                             49.08
# Df Model:                           1
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# Intercept           20.0340      1.118     17.916      0.000      17.455      22.613
# taxon[T.Myxozoa]    -3.5340      1.581     -2.235      0.056      -7.181       0.113
# ==============================================================================
# Omnibus:                        1.006   Durbin-Watson:                   1.401
# Prob(Omnibus):                  0.605   Jarque-Bera (JB):                0.356
# Skew:                          -0.448   Prob(JB):                        0.837
# Kurtosis:                       2.772   Cond. No.                         2.62
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# analyzing nucleotide composition G
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             proportion   R-squared:                       0.364
# Model:                            OLS   Adj. R-squared:                  0.285
# Method:                 Least Squares   F-statistic:                     4.583
# Date:                Wed, 15 Mar 2023   Prob (F-statistic):             0.0647
# Time:                        21:58:32   Log-Likelihood:                -23.755
# No. Observations:                  10   AIC:                             51.51
# Df Residuals:                       8   BIC:                             52.12
# Df Model:                           1
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# Intercept           22.3360      1.301     17.163      0.000      19.335      25.337
# taxon[T.Myxozoa]    -3.9400      1.840     -2.141      0.065      -8.184       0.304
# ==============================================================================
# Omnibus:                        0.017   Durbin-Watson:                   1.228
# Prob(Omnibus):                  0.991   Jarque-Bera (JB):                0.199
# Skew:                           0.073   Prob(JB):                        0.905
# Kurtosis:                       2.324   Cond. No.                         2.62
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# /opt/anaconda3/lib/python3.9/site-packages/scipy/stats/stats.py:1541: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=10
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "
# /opt/anaconda3/lib/python3.9/site-packages/scipy/stats/stats.py:1541: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=10
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "
# /opt/anaconda3/lib/python3.9/site-packages/scipy/stats/stats.py:1541: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=10
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "
# /opt/anaconda3/lib/python3.9/site-packages/scipy/stats/stats.py:1541: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=10
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "

# %%
nucleotide_data = pd.read_csv("final_nucleotide_composition.csv")
nucleotide_data['proportion'] = nucleotide_data['proportion'].str.rstrip('%').astype('float')
mono_contigency_table = pd.crosstab(nucleotide_data['taxon'], nucleotide_data['nucleotide_counted'], nucleotide_data['count'], aggfunc=sum)

mono_contigency_table
# Out:
# nucleotide_counted         A         C         G         T
# taxon
# Coral               80924004  51978795  57711359  67498278
# Myxozoa              6831864   3688862   3737876   6116488

# %%
stat, p, dof, expected = chi2_contingency(mono_contigency_table)
prob = .95
chi = chi2.ppf(prob, dof)


if abs(stat) >= chi:
    print('reject Ho')
else:
    print('fail to reject Ho')


print("pvalue",p)
print("stat",stat)
print("dof",dof)
# Out:
# reject Ho
# pvalue 0.0
# stat 312288.14159274515
# dof 3

# %%
Dinucleotide_data = pd.read_csv("Dinucleotide_composition.csv")
Dinucleotide_data['proportion'] = Dinucleotide_data['proportion'].str.rstrip('%').astype('float')

Dinucleotide_data
# Out:
#                      species    taxon Dinucleotide_counted    count  \
# 0           Enteromyxum leei  Myxozoa                   CG       92
# 1           Enteromyxum leei  Myxozoa                   GC      210
# 2      Henneguya salminicola  Myxozoa                   CG   152392
# 3      Henneguya salminicola  Myxozoa                   GC   166940
# 4               Kudoa iwatai  Myxozoa                   CG       11
# 5               Kudoa iwatai  Myxozoa                   GC       77
# 6        Myxobolus squamalis  Myxozoa                   CG    98466
# 7        Myxobolus squamalis  Myxozoa                   GC   124283
# 8      Thelohanellus kitauei  Myxozoa                   CG   393133
# 9      Thelohanellus kitauei  Myxozoa                   GC   378201
# 10       Acropora digitifera    Coral                   CG  1558373
# 11       Acropora digitifera    Coral                   GC  2285919
# 12    Pocillopora damicornis    Coral                   CG  1328783
# 13    Pocillopora damicornis    Coral                   GC  1905375
# 14  Nematostella vectensis\n    Coral                   CG  3114532
# 15  Nematostella vectensis\n    Coral                   GC  3931953
# 16     Exaiptasia diaphana\n    Coral                   CG  1291088
# 17     Exaiptasia diaphana\n    Coral                   GC  1857918
# 18            Hydra vulgaris    Coral                   CG   894419
# 19            Hydra vulgaris    Coral                   GC  1800312
#
#     proportion
# 0         1.09
# 1         2.99
# 2         2.64
# 3         2.89
# 4         0.15
# 5         1.02
# 6         2.61
# 7         3.29
# 8         3.64
# 9         3.50
# 10        3.30
# 11        4.83
# 12        3.25
# 13        4.66
# 14        4.53
# 15        5.71
# 16        2.93
# 17        4.21
# 18        1.57
# 19        3.16

# %%
# Style changes the background of the graph. Set the parameters that control the scaling of plot elements
sb.set_context("talk")
sb.set_theme(style='white')
fig,ax = plt.subplots()

#Creates ViolinPlot & BoxPlot, Palette controls the colors of the data and hue creates the ledger 
sb.boxplot( x = 'Dinucleotide_counted',y = 'proportion', palette=['orange','lightsteelblue'], data = Dinucleotide_data, hue = 'taxon' , boxprops={'alpha': .5}).set(title='Proportion vs DiNucleotide Count')
sb.swarmplot( x = 'Dinucleotide_counted',y = 'proportion', palette=['orange','lightsteelblue'], data = Dinucleotide_data, hue = 'taxon', dodge = True, zorder=.5, size=8 )

#Shift the ledger to the right
plt.legend(bbox_to_anchor=(1.35, 1), borderaxespad=0, frameon=False)

## Remove axis lines.
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

fig.savefig("Proportion_vs_DiNucleotide_Counted_Box_Plot.png",dpi=300,bbox_inches="tight")
plt.show()

# %%
# Style changes the background of the graph. Set the parameters that control the scaling of plot elements
fig,ax = plt.subplots()
sb.set_context("talk")
sb.set_theme(style='white')

# Creates ViolinPlot, Palette controls the colors of the data and hue creates the ledger 
sns.violinplot(x="Dinucleotide_counted", y="proportion", hue="taxon", data=Dinucleotide_data, palette=['orange','lightsteelblue']).set(title='Proportion vs DiNucleotide Count')

#Shift the ledger to the right
plt.legend(bbox_to_anchor=(1.35, 1), borderaxespad=0, frameon=False)

## Remove axis lines.
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

fig.savefig("Proportion_vs_DiNucleotide_Counted_Violin_Plot.png",dpi=300,bbox_inches="tight")
plt.show()

# %%
sns.set_style('white')
palette = sns.cubehelix_palette(start=.5, rot=-.5, dark=0.3, light=0.7)
ax = sns.violinplot(y="proportion", x="Dinucleotide_counted", data=Dinucleotide_data, palette=['orange','lightsteelblue'], scale="width", inner=None)

xlim = ax.get_xlim()
ylim = ax.get_ylim()

for violin in ax.collections:
    bbox = violin.get_paths()[0].get_extents()
    x0, y0, width, height = bbox.bounds
    violin.set_clip_path(plt.Rectangle((x0, y0), width, height / 2, transform=ax.transData))

sns.boxplot(y="proportion", x="Dinucleotide_counted", data=Dinucleotide_data, saturation=1, showfliers=False, width=0.3, hue="taxon", boxprops={'zorder': 3, 'facecolor': 'none'}, ax=ax).set(title='Proportion vs DiNucleotide Count')
Dinucleotide_collections = len(ax.collections)
sns.stripplot(y="proportion", x="Dinucleotide_counted", data=Dinucleotide_data, ax=ax, hue="taxon")
for dots in ax.collections[Dinucleotide_collections:]:
    dots.set_offsets(dots.get_offsets() + np.array([0, 0.1]))

ax.set_xlim(xlim)
ax.set_ylim(ylim)
plt.legend(bbox_to_anchor=(1.35, 1), borderaxespad=0, frameon=False)

## Remove axis lines.
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

fig.savefig("Proportion_vs_DiNucleotide_Counted.png",dpi=300,bbox_inches="tight")
plt.show()

# %%
rows_with_GC = Dinucleotide_data['Dinucleotide_counted'] == 'GC'
Dinucleotide_GC_data = Dinucleotide_data[rows_with_GC]

Dinucleotide_GC_data
# Out:
#                      species    taxon Dinucleotide_counted    count  \
# 1           Enteromyxum leei  Myxozoa                   GC      210
# 3      Henneguya salminicola  Myxozoa                   GC   166940
# 5               Kudoa iwatai  Myxozoa                   GC       77
# 7        Myxobolus squamalis  Myxozoa                   GC   124283
# 9      Thelohanellus kitauei  Myxozoa                   GC   378201
# 11       Acropora digitifera    Coral                   GC  2285919
# 13    Pocillopora damicornis    Coral                   GC  1905375
# 15  Nematostella vectensis\n    Coral                   GC  3931953
# 17     Exaiptasia diaphana\n    Coral                   GC  1857918
# 19            Hydra vulgaris    Coral                   GC  1800312
#
#     proportion
# 1         2.99
# 3         2.89
# 5         1.02
# 7         3.29
# 9         3.50
# 11        4.83
# 13        4.66
# 15        5.71
# 17        4.21
# 19        3.16

# %%
Dinucleotides = ['GC','CG']
for Dinucleotide in Dinucleotides:
    rows_with_GC = Dinucleotide_data['Dinucleotide_counted'] == Dinucleotide
    Dinucleotide_GC_data = Dinucleotide_data[rows_with_GC]
    print(f'analyzing nucleotide composition {Dinucleotide}')
    
    Dinucleotide_GC_data
    model = smf.ols(formula='proportion ~ taxon', data=Dinucleotide_GC_data)
    results = model.fit()
    summary = results.summary()
    print(summary)
    output_file = open(f"Dinucleotide_{Dinucleotide}_Stats_Results.txt", "w")
    output_file.write(str(summary))
    output_file.close()
# Out:
# analyzing nucleotide composition GC
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             proportion   R-squared:                       0.516
# Model:                            OLS   Adj. R-squared:                  0.455
# Method:                 Least Squares   F-statistic:                     8.524
# Date:                Wed, 15 Mar 2023   Prob (F-statistic):             0.0193
# Time:                        21:59:44   Log-Likelihood:                -12.684
# No. Observations:                  10   AIC:                             29.37
# Df Residuals:                       8   BIC:                             29.97
# Df Model:                           1
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# Intercept            4.5140      0.430     10.494      0.000       3.522       5.506
# taxon[T.Myxozoa]    -1.7760      0.608     -2.920      0.019      -3.179      -0.373
# ==============================================================================
# Omnibus:                        2.265   Durbin-Watson:                   1.809
# Prob(Omnibus):                  0.322   Jarque-Bera (JB):                1.162
# Skew:                          -0.818   Prob(JB):                        0.559
# Kurtosis:                       2.661   Cond. No.                         2.62
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# analyzing nucleotide composition CG
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             proportion   R-squared:                       0.196
# Model:                            OLS   Adj. R-squared:                  0.095
# Method:                 Least Squares   F-statistic:                     1.949
# Date:                Wed, 15 Mar 2023   Prob (F-statistic):              0.200
# Time:                        21:59:44   Log-Likelihood:                -15.181
# No. Observations:                  10   AIC:                             34.36
# Df Residuals:                       8   BIC:                             34.97
# Df Model:                           1
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# Intercept            3.1160      0.552      5.643      0.000       1.843       4.389
# taxon[T.Myxozoa]    -1.0900      0.781     -1.396      0.200      -2.891       0.711
# ==============================================================================
# Omnibus:                        0.499   Durbin-Watson:                   1.953
# Prob(Omnibus):                  0.779   Jarque-Bera (JB):                0.530
# Skew:                          -0.271   Prob(JB):                        0.767
# Kurtosis:                       2.011   Cond. No.                         2.62
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# /opt/anaconda3/lib/python3.9/site-packages/scipy/stats/stats.py:1541: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=10
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "
# /opt/anaconda3/lib/python3.9/site-packages/scipy/stats/stats.py:1541: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=10
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "

# %%
from scipy.stats import chi2_contingency
from scipy.stats import chi2

# %%
Dinucleotide_data = pd.read_csv("Dinucleotide_composition.csv")
Dinucleotide_data['proportion'] = Dinucleotide_data['proportion'].str.rstrip('%').astype('float')
contigency_table = pd.crosstab(Dinucleotide_data['taxon'], Dinucleotide_data['Dinucleotide_counted'], Dinucleotide_data['count'], aggfunc=sum)

contigency_table
# Out:
# Dinucleotide_counted       CG        GC
# taxon
# Coral                 8187195  11781477
# Myxozoa                644094    669711

# %%
stat, p, dof, expected = chi2_contingency(contigency_table)
prob = .95
chi = chi2.ppf(prob, dof)


if abs(stat) >= chi:
    print('reject Ho')
else:
    print('fail to reject Ho')

print("pvalue",p)
print("stat",stat)
print("dof",dof)
# Out:
# reject Ho
# pvalue 0.0
# stat 32699.47073428636
# dof 1
